# %% [markdown]
# # Fundamentos de machine learning con python
#
# ## Classifications and regression Tress (CART)
#
# Métodología de aprendizaje supervisado para contstruir ARBOLES DE DECISIÓN mediante particiones sucesivas de los datos, aplicable tanto problemas de clasificación como regresión. Los árboles transforman relaciones complejas entre variables en una regla de decisión
